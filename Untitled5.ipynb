# %% [markdown]
# <a href="https://colab.research.google.com/github/geetika001/ml/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
I=Image.open("scenery.jpeg")

# %%
print('Size of Image: ', I.size)
# Out:
# Size of Image:  (300, 168)

# %%
Image.open("scenery.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %% [markdown]
# # **Using Matplotlib**

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('scenery.jpeg')

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# #**Using OpenCV**

# %%
import cv2

# %%
img=cv2.imread("scenery.jpeg")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %% [markdown]
# #**Using scikit-image**

# %%
import skimage.io as io

# %%
image=io.imread('scenery.jpeg')

# %%
io.imshow(image)

# %% [markdown]
# #**Writing and Saving Images**
#
# ###**Use PIL: using save function**

# %%
I=Image.open('scenery.jpeg')

# %%
I1=I.save("Image1.jpeg")

# %%
Image.open("Image1.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %% [markdown]
# ###**Using OpenCV**

# %%
image=cv2.imread("scenery.jpeg")

# %%
filename='savedImage.jpeg'
cv2.imwrite(filename,image[:,:200,:100])
# Out:
# True

# %%
img=cv2.imread('savedImage.jpeg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x168>

# %% [markdown]
# ###**Using scikit-image**

# %%
import skimage.io as io
from skimage.transform import rescale
import numpy as np

# %%
import numpy as np
import skimage.io as io
from skimage.transform import rescale
from skimage.color import rgb2gray

# Reading the image using its path
image = io.imread('scenery.jpeg')

# Rescale the image by a scaling factor of 0.7
rescaled_image = rescale(image, 0.7)

# Convert the image to a format supported by PIL
rescaled_image = (rescaled_image * 255).astype(np.uint8)
rescaled_image = rescaled_image[:, :, 0]

# Save the rescaled image with a filename
filename = 'savedImage.jpeg'
io.imsave(filename, rescaled_image)

# Display the rescaled image

io.imshow(rescaled_image)
io.show()

# %% [markdown]
# #**IMAGE AUGMENTATION**

# %%
#importing all the required lib
import skimage.io as io
from skimage.transform import rotate
import numpy as np
import matplotlib.pyplot as plt
image=io.imread('scenery.jpeg')
def image_augment(image):
  fig, ax=plt.subplots(nrows=1,ncols=3,figsize=(9,8))
  ax[0].imshow(image)
  ax[0].axis('off')
  ax[1].imshow(rotate(image,angle=45,mode='wrap'))
  ax[1].axis('off')
  ax[2].imshow(np.fliplr(image))
  ax[2].axis('off')
image_augment(image)
